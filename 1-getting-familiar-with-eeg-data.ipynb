# %% [markdown]
# # Getting familiar with EEG data
#
#
# Javi Rameerez <javi@rameerez.com> | [@rameerez [tw]](http://twitter.com/rameerez)
#
# This code is Open Source, released under a GPL License.

# %% [markdown]
# We will use data from publicly available datasets as a way to get familiar with EEG data. More concisely, we will be using a single patient's sample of [this](https://www.kaggle.com/c/grasp-and-lift-eeg-detection/data) dataset.

# %%
import pandas as pd

# %matplotlib inline

# %%
# Data source: https://www.kaggle.com/c/grasp-and-lift-eeg-detection/data
df = pd.read_csv("data/external-examples/subj1_series1_data.csv")

# %%
df['F7'][:500].plot(figsize=(20, 20))

# %%
df.describe()
# Out:
#                  Fp1            Fp2             F7             F3  \
# count  119496.000000  119496.000000  119496.000000  119496.000000
# mean      265.934374     404.173194     398.503774     215.615385
# std       373.911366     313.686274     207.645572     204.065055
# min     -1051.000000    -532.000000    -752.000000    -466.000000
# 25%        43.000000     218.000000     253.000000      76.000000
# 50%       210.000000     360.000000     389.000000     210.000000
# 75%       404.000000     515.000000     534.000000     356.000000
# max      3101.000000    3047.000000    1479.000000    1253.000000
#
#                   Fz             F4             F8            FC5  \
# count  119496.000000  119496.000000  119496.000000  119496.000000
# mean      144.392189     443.437395    -122.864221     474.953538
# std       141.130921     221.457186     479.160803     198.874064
# min      -262.000000    -634.000000   -4095.000000    -893.000000
# ...

# %%
df.T
# Out:
#                0                1                2                3       \
# id    subj1_series1_0  subj1_series1_1  subj1_series1_2  subj1_series1_3
# Fp1               -31              -29             -172             -272
# Fp2               363              342              278              263
# F7                211              216              105              -52
# F3                121              123               93               99
# Fz                211              222              222              208
# F4                 15              200              511              511
# F8                717              595              471              428
# FC5               279              329              280              261
# FC1                35               43               12               27
# FC2               158              166              177              180
# FC6               543              495              534              525
# ...

# %%
df["Fp2"].plot()

# %%
df.plot(subplots=True, figsize=(16, 16))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1232c9898>,
# ...
#       dtype=object)

# %%
len(df["Fp1"].values)/500/60
# Out:
# 3.9831999999999996
